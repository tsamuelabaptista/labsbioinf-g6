# %% [markdown]
# # BLAST

# %%
from Bio.Blast import NCBIXML 
from Bio.Blast import NCBIWWW

# %%
def blast(accession : str, program : str, database : str, filename : str):
    """
    função que executa um blast de uma sequência do NCBI e guarda o resultado
    recebe o identificador da seq no NCBI, o tipo de programa de blast, a base de dados usada 
    e o nome do ficheiro que queremos guardar a informação
    """
    result_handle = NCBIWWW.qblast(program, database, accession)

    save_file = open(filename, "w")
    save_file.write(result_handle.read())
    save_file.close()
    result_handle.close()

    result_handle = open(filename)

    blast_record = NCBIXML.read(result_handle)

    return blast_record

# %%
flg_blast_record = blast("60097902", "blastp", "swissprot", "flg_protein_blast")

# %%
def blast_analysis(blast_record, e_value_threshold : float, coverage_threshold : float):
    print(len(blast_record.alignments), "hits")
    for alignment in blast_record.alignments:
        for hsp in alignment.hsps:
            coverage = hsp.align_length / blast_record.query_length
            if hsp.expect <= e_value_threshold and coverage >= coverage_threshold:
                print ('\n****Alignment****')
                print ('sequence:', alignment.title)
                print ('length:', alignment.length)
                print ('e value:', hsp.expect)

# %%
blast_analysis(flg_blast_record, 0.05, 0)
# Out:
# 22 hits
#
# ****Alignment****
# sequence: sp|P20930.3| RecName: Full=Filaggrin [Homo sapiens]
# length: 4061
# e value: 0.0
#
# ****Alignment****
# sequence: sp|Q8VHD8.1| RecName: Full=Hornerin [Mus musculus]
# length: 2496
# e value: 7.52798e-46
#
# ****Alignment****
# sequence: sp|Q86YZ3.2| RecName: Full=Hornerin [Homo sapiens]
# length: 2850
# e value: 3.60979e-38
#
# ****Alignment****
# sequence: sp|Q5D862.1| RecName: Full=Filaggrin-2; Short=FLG-2; AltName: Full=Intermediate filament-associated and psoriasis-susceptibility protein; Short=Ifapsoriasin [Homo sapiens]
# length: 2391
# e value: 7.59274e-38
#
# ****Alignment****
# sequence: sp|Q5D862.1| RecName: Full=Filaggrin-2; Short=FLG-2; AltName: Full=Intermediate filament-associated and psoriasis-susceptibility protein; Short=Ifapsoriasin [Homo sapiens]
# length: 2391
# e value: 2.10116e-30
#
# ****Alignment****
# sequence: sp|Q5D862.1| RecName: Full=Filaggrin-2; Short=FLG-2; AltName: Full=Intermediate filament-associated and psoriasis-susceptibility protein; Short=Ifapsoriasin [Homo sapiens]
# length: 2391
# e value: 3.08341e-29
#
# ****Alignment****
# sequence: sp|Q5D862.1| RecName: Full=Filaggrin-2; Short=FLG-2; AltName: Full=Intermediate filament-associated and psoriasis-susceptibility protein; Short=Ifapsoriasin [Homo sapiens]
# length: 2391
# e value: 2.61726e-15
#
# ****Alignment****
# sequence: sp|Q2VIS4.2| RecName: Full=Filaggrin-2; Short=FLG-2; AltName: Full=Intermediate filament-associated protein [Mus musculus]
# length: 2362
# e value: 4.15295e-37
#
# ****Alignment****
# sequence: sp|Q6XPR3.1| RecName: Full=Repetin [Homo sapiens]
# length: 784
# e value: 5.91058e-23
#
# ****Alignment****
# sequence: sp|Q9UBG3.1| RecName: Full=Cornulin; AltName: Full=53 kDa putative calcium-binding protein; AltName: Full=53 kDa squamous epithelial-induced stress protein; AltName: Full=58 kDa heat shock protein; AltName: Full=Squamous epithelial heat shock protein 53; AltName: Full=Tumor-related protein [Homo sapiens]
# length: 495
# e value: 9.96006e-23
#
# ****Alignment****
# sequence: sp|P97347.2| RecName: Full=Repetin [Mus musculus]
# length: 1118
# e value: 1.57816e-21
#
# ****Alignment****
# sequence: sp|P22793.2| RecName: Full=Trichohyalin [Ovis aries]
# length: 1549
# e value: 6.24023e-14
#
# ****Alignment****
# sequence: sp|P80310.2| RecName: Full=Protein S100-A12; AltName: Full=Calgranulin-C; Short=CAGC; AltName: Full=Extracellular newly identified RAGE-binding protein; Short=EN-RAGE; AltName: Full=S100 calcium-binding protein A12 [Sus scrofa]
# length: 92
# e value: 6.23094e-11
#
# ****Alignment****
# sequence: sp|P80511.2| RecName: Full=Protein S100-A12; AltName: Full=CGRP; AltName: Full=Calcium-binding protein in amniotic fluid 1; Short=CAAF1; AltName: Full=Calgranulin-C; Short=CAGC; AltName: Full=Extracellular newly identified RAGE-binding protein; Short=EN-RAGE; AltName: Full=Migration inhibitory factor-related protein 6; Short=MRP-6; Short=p6; AltName: Full=Neutrophil S100 protein; AltName: Full=S100 calcium-binding protein A12; Contains: RecName: Full=Calcitermin [Homo sapiens]
# length: 92
# e value: 7.5719e-11
#
# ****Alignment****
# sequence: sp|P79105.3| RecName: Full=Protein S100-A12; AltName: Full=Calcium-binding protein in amniotic fluid 1; Short=CAAF1; AltName: Full=Calgranulin-C; Short=CAGC; AltName: Full=Cornea-associated antigen; Short=CO-AG; AltName: Full=Extracellular newly identified RAGE-binding protein; Short=EN-RAGE; AltName: Full=RAGE-binding protein; AltName: Full=S100 calcium-binding protein A12 [Bos taurus]
# length: 92
# e value: 1.93e-10
#
# ****Alignment****
# sequence: sp|Q07283.2| RecName: Full=Trichohyalin [Homo sapiens]
# length: 1943
# e value: 9.03182e-10
#
# ****Alignment****
# sequence: sp|P25815.2| RecName: Full=Protein S100-P; AltName: Full=Migration-inducing gene 9 protein; Short=MIG9; AltName: Full=Protein S100-E; AltName: Full=S100 calcium-binding protein P [Homo sapiens]
# length: 95
# e value: 9.59513e-10
#
# ****Alignment****
# sequence: sp|O77791.4| RecName: Full=Protein S100-A12; AltName: Full=Calgranulin-C; Short=CAGC; AltName: Full=Extracellular newly identified RAGE-binding protein; Short=EN-RAGE; AltName: Full=S100 calcium-binding protein A12 [Oryctolagus cuniculus]
# length: 92
# e value: 1.74723e-09
#
# ****Alignment****
# sequence: sp|P37709.1| RecName: Full=Trichohyalin [Oryctolagus cuniculus]
# length: 1407
# e value: 6.39984e-09
#
# ****Alignment****
# sequence: sp|P28318.1| RecName: Full=Protein MRP-126 [Gallus gallus]
# length: 119
# e value: 5.35719e-08
#
# ****Alignment****
# sequence: sp|P02638.2| RecName: Full=Protein S100-B; AltName: Full=S-100 protein beta chain; AltName: Full=S-100 protein subunit beta; AltName: Full=S100 calcium-binding protein B [Bos taurus]
# length: 92
# e value: 6.07993e-08
#
# ****Alignment****
# sequence: sp|P28783.3| RecName: Full=Protein S100-A9; AltName: Full=BEE22; AltName: Full=Calgranulin-B; AltName: Full=Neutrophil cytosolic 23 kDa protein; Short=p23; AltName: Full=S100 calcium-binding protein A9 [Bos taurus]
# length: 156
# e value: 7.8384e-08
#
# ****Alignment****
# sequence: sp|P31725.3| RecName: Full=Protein S100-A9; AltName: Full=Calgranulin-B; AltName: Full=Leukocyte L1 complex heavy chain; AltName: Full=Migration inhibitory factor-related protein 14; Short=MRP-14; Short=p14; AltName: Full=S100 calcium-binding protein A9 [Mus musculus]
# length: 113
# e value: 1.00635e-05
#
# ****Alignment****
# sequence: sp|P50116.3| RecName: Full=Protein S100-A9; AltName: Full=Calgranulin-B; AltName: Full=Migration inhibitory factor-related protein 14; Short=MRP-14; Short=p14; AltName: Full=Myeloid-related protein 14; AltName: Full=S100 calcium-binding protein A9 [Rattus norvegicus]
# length: 113
# e value: 1.8192e-05
